# %% [markdown]
# # Rightmove - Building a dataset of property listings
#
# ---
#
# This notebook will create a csv file with the following information for each property listing:
#
#
# *   Price
# *   Property link
# *   Number of bedrooms
# *   Address of property
#
# Going into much details for each property slows down the code quite a bit.

# %%
# importing our libraries

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import random

"""
Rightmove uses specific codes to describe each London borough, I have 
manually collected these codes by search for each borough individually.
"""

BOROUGHS = {
    "City of London": "5E61224",
    "Barking and Dagenham": "5E61400",
    "Barnet": "5E93929",
    "Bexley": "5E93932",
    "Brent": "5E93935",
    "Bromley": "5E93938",
    "Camden": "5E93941",
    "Croydon": "5E93944",
    "Ealing": "5E93947",
    "Enfield": "5E93950",
    "Greenwich": "5E61226",
    "Hackney": "5E93953",
    "Hammersmith and Fulham": "5E61407",
    "Haringey": "5E61227",
    "Harrow": "5E93956",
    "Havering": "5E61228",
    "Hillingdon": "5E93959",
    "Hounslow": "5E93962",
    "Islington": "5E93965",
    "Kensington and Chelsea": "5E61229",
    "Kingston upon Thames": "5E93968",
    "Lambeth": "5E93971",
    "Lewisham": "5E61413",
    "Merton": "5E61414",
    "Newham": "5E61231",
    "Redbridge": "5E61537",
    "Richmond upon Thames": "5E61415",
    "Southwark": "5E61518",
    "Sutton": "5E93974",
    "Tower Hamlets": "5E61417",
    "Waltham Forest": "5E61232",
    "Wandsworth": "5E93977",
    "Westminster": "5E93980",
}

# %%
def main():

    # initialise index, this tracks the page number we are on. every additional page adds 24 to the index

    # create lists to store our data
    all_apartment_links = []
    all_description = []
    all_address = []
    all_price = []

    # apparently the maximum page limit for rightmove is 42
    for borough in list(BOROUGHS.values()):

        # initialise index, this tracks the page number we are on. every additional page adds 24 to the index
        index = 0

        key = [key for key, value in BOROUGHS.items() if value == borough]
        print(f"We are scraping the borough named: {key}")
        for pages in range(41):

            # define our user headers
            headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36"
            }

            # the website changes if the you are on page 1 as compared to other pages
            if index == 0:
                rightmove = f"https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%{borough}&sortType=6&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="

            elif index != 0:
                rightmove = f"https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%{borough}&sortType=6&index={index}&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="

            # request our webpage
            res = requests.get(rightmove, headers=headers)

            # check status
            res.raise_for_status()

            soup = BeautifulSoup(res.text, "html.parser")

            # This gets the list of apartments
            apartments = soup.find_all("div", class_="l-searchResult is-list")

            # This gets the number of listings
            number_of_listings = soup.find(
                "span", {"class": "searchHeader-resultCount"}
            )
            number_of_listings = number_of_listings.get_text()
            number_of_listings = int(number_of_listings.replace(",", ""))

            for i in range(len(apartments)):

                # tracks which apartment we are on in the page
                apartment_no = apartments[i]

                # append link
                apartment_info = apartment_no.find("a", class_="propertyCard-link")
                link = "https://www.rightmove.co.uk" + apartment_info.attrs["href"]
                all_apartment_links.append(link)

                # append address
                address = (
                    apartment_info.find("address", class_="propertyCard-address")
                    .get_text()
                    .strip()
                )
                all_address.append(address)

                # append description
                description = (
                    apartment_info.find("h2", class_="propertyCard-title")
                    .get_text()
                    .strip()
                )
                all_description.append(description)

                # append price
                price = (
                    apartment_no.find("div", class_="propertyCard-priceValue")
                    .get_text()
                    .strip()
                )
                all_price.append(price)

            print(f"You have scrapped {pages + 1} pages of apartment listings.")
            print(f"You have {number_of_listings - index} listings left to go")
            print("\n")

            # code to ensure that we do not overwhelm the website
            time.sleep(random.randint(1, 3))

            # Code to count how many listings we have scrapped already.
            index = index + 24

            if index >= number_of_listings:
                break

    # convert data to dataframe
    data = {
        "Links": all_apartment_links,
        "Address": all_address,
        "Description": all_description,
        "Price": all_price,
    }
    df = pd.DataFrame.from_dict(data)
    df.to_csv(r"sales_data.csv", encoding="utf-8", header="true", index = False)


if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2257 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2236 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2209 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2185 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2162 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2137 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 2113 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 2089 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 2065 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 2041 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 2017 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1996 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1970 listings left to go
#
#
# We are scraping the borough named: ['Bexley']
# You have scrapped 1 pages of apartment listings.
# You have 1043 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1018 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 995 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 971 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 948 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 923 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 900 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 874 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 852 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 826 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 804 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 780 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 755 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 732 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 707 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 683 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 659 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 636 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 610 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 588 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 563 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 539 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 516 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 491 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 468 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 442 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 420 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 395 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 372 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 348 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 323 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 299 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 275 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 251 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 227 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 203 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 179 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 154 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 131 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 108 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 84 listings left to go
#
#
# We are scraping the borough named: ['Brent']
# You have scrapped 1 pages of apartment listings.
# You have 1835 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1811 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1787 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1763 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1738 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1714 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1690 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1666 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1642 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1618 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1594 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1570 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1546 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1522 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1499 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1474 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1450 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1426 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1402 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1379 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1354 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1330 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1306 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1282 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1258 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1234 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1210 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1186 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1162 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1139 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1114 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1090 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1066 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1042 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1018 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 995 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 971 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 946 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 922 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 898 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 874 listings left to go
#
#
# We are scraping the borough named: ['Bromley']
# You have scrapped 1 pages of apartment listings.
# You have 2144 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2120 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2096 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2072 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2048 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2024 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2000 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1976 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1952 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1928 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1904 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1880 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1856 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1832 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1808 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1784 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1760 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1736 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1712 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1688 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1664 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1640 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1616 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1592 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1568 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1544 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1520 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1496 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1472 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1448 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1424 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1400 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1376 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1352 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1328 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1304 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1280 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1256 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1232 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1208 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1184 listings left to go
#
#
# We are scraping the borough named: ['Camden']
# You have scrapped 1 pages of apartment listings.
# You have 1987 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1963 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1938 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1915 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1891 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1867 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1843 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1819 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1795 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1771 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1747 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1723 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1699 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1675 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1651 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1627 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1603 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1578 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1555 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1531 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1507 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1483 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1459 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1434 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1411 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1387 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1363 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1339 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1315 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1291 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1267 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1243 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1219 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1195 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1171 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1147 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1122 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1099 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1075 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1051 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1027 listings left to go
#
#
# We are scraping the borough named: ['Croydon']
# You have scrapped 1 pages of apartment listings.
# You have 2800 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2776 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2751 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2727 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2703 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2679 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2655 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2632 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2608 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2584 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2560 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2536 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2512 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2487 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2463 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2440 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2416 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2391 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2368 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2344 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2319 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2296 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2272 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2248 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2224 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2199 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 2175 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2152 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2128 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2104 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2080 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2056 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2032 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2008 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1984 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1960 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1935 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1912 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1887 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1864 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1839 listings left to go
#
#
# We are scraping the borough named: ['Ealing']
# You have scrapped 1 pages of apartment listings.
# You have 2324 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2300 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2276 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2252 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2228 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2204 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2180 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2156 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2132 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2108 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2084 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2060 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2036 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2012 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1988 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1964 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1940 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1916 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1892 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1868 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1844 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1820 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1796 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1772 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1748 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1724 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1700 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1676 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1652 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1628 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1604 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1580 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1556 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1532 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1508 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1484 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1460 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1436 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1412 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1388 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1364 listings left to go
#
#
# We are scraping the borough named: ['Enfield']
# You have scrapped 1 pages of apartment listings.
# You have 1537 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1513 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1488 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1465 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1441 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1417 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1393 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1369 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1345 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1321 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1296 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1272 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1249 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1225 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1201 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1177 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1153 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1128 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1105 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1081 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1057 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1033 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1009 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 985 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 961 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 937 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 913 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 889 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 865 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 841 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 817 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 793 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 768 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 744 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 721 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 697 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 673 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 648 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 624 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 601 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 577 listings left to go
#
#
# We are scraping the borough named: ['Greenwich']
# You have scrapped 1 pages of apartment listings.
# You have 1531 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1507 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1483 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1459 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1435 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1411 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1387 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1363 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1339 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1315 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1291 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1267 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1243 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1219 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1195 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1171 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1147 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1123 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1099 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1075 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1051 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1027 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1003 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 979 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 955 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 931 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 907 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 883 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 859 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 835 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 811 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 787 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 763 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 739 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 715 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 691 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 667 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 643 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 619 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 595 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 571 listings left to go
#
#
# We are scraping the borough named: ['Hackney']
# You have scrapped 1 pages of apartment listings.
# You have 1440 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1416 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1392 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1368 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1344 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1320 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1296 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1272 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1248 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1224 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1200 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1176 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1152 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1128 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1104 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1080 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1056 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1032 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1008 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 984 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 960 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 936 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 912 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 888 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 864 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 840 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 816 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 792 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 768 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 744 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 720 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 696 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 672 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 648 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 624 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 600 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 576 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 552 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 528 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 504 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 480 listings left to go
#
#
# We are scraping the borough named: ['Hammersmith and Fulham']
# You have scrapped 1 pages of apartment listings.
# You have 2133 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2110 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2085 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2062 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2038 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2014 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1989 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1966 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1942 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1917 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1894 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1869 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1846 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1822 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1798 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1773 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1749 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1726 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1702 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1677 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1654 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1630 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1606 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1582 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1558 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1534 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1510 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1486 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1462 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1437 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1414 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1390 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1366 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1341 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1318 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1294 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1270 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1246 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1222 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1198 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1173 listings left to go
#
#
# We are scraping the borough named: ['Haringey']
# You have scrapped 1 pages of apartment listings.
# You have 1298 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1274 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1250 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1226 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1202 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1175 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1151 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1130 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1103 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1082 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1058 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1034 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1007 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 986 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 962 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 938 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 911 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 890 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 863 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 842 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 818 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 794 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 770 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 746 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 722 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 698 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 674 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 650 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 626 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 599 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 575 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 554 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 530 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 506 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 482 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 458 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 434 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 410 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 383 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 362 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 338 listings left to go
#
#
# We are scraping the borough named: ['Harrow']
# You have scrapped 1 pages of apartment listings.
# You have 1423 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1399 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1375 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1351 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1327 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1303 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1279 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1255 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1231 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1207 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1183 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1159 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1135 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1111 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1087 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1063 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1039 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1015 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 991 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 967 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 943 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 919 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 895 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 871 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 847 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 823 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 799 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 775 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 751 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 727 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 703 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 679 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 655 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 631 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 607 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 583 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 559 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 535 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 511 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 487 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 463 listings left to go
#
#
# We are scraping the borough named: ['Havering']
# You have scrapped 1 pages of apartment listings.
# You have 1455 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1431 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1407 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1383 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1359 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1335 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1311 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1287 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1263 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1239 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1215 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1191 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1167 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1143 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1119 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1095 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1071 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1047 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1023 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 999 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 975 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 951 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 927 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 903 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 879 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 855 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 831 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 807 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 783 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 759 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 735 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 711 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 687 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 663 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 639 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 615 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 591 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 567 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 543 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 519 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 495 listings left to go
#
#
# We are scraping the borough named: ['Hillingdon']
# You have scrapped 1 pages of apartment listings.
# You have 1503 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1479 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1455 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1431 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1407 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1383 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1359 listings left to go
#
#
# ...
# You have 502 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 478 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 455 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 430 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 406 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 382 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 358 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 335 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 310 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 287 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 262 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 238 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 214 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 191 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 166 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 142 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 119 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 94 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 70 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 46 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 22 listings left to go
#
#
# We are scraping the borough named: ['Tower Hamlets']
# You have scrapped 1 pages of apartment listings.
# You have 2793 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2771 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2749 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2725 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2697 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2677 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2649 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2625 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2603 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2579 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2557 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2533 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2507 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2485 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2461 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2435 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2413 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2385 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2363 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2339 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2313 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2293 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2269 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2245 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2219 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2197 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 2169 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2149 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2121 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2099 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2077 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2053 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2029 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2005 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1981 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1953 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1933 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1907 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1883 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1861 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1835 listings left to go
#
#
# We are scraping the borough named: ['Waltham Forest']
# You have scrapped 1 pages of apartment listings.
# You have 1148 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1125 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1101 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1077 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1054 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1029 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1005 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 980 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 958 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 932 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 908 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 884 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 860 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 838 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 813 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 789 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 765 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 742 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 718 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 692 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 670 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 645 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 620 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 597 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 573 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 549 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 526 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 501 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 477 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 453 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 429 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 404 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 382 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 357 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 332 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 308 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 284 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 261 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 237 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 213 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 189 listings left to go
#
#
# We are scraping the borough named: ['Wandsworth']
# You have scrapped 1 pages of apartment listings.
# You have 3228 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 3194 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 3180 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 3156 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 3121 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 3097 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 3084 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 3060 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 3025 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 3012 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2988 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2964 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2940 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2916 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2892 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2858 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2844 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2810 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2796 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2761 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2748 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2713 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2700 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2666 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2652 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2628 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 2604 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2570 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2556 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2521 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2508 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2484 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2449 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2436 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 2401 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 2378 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 2353 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 2330 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 2316 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 2292 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 2257 listings left to go
#
#
# We are scraping the borough named: ['Westminster']
# You have scrapped 1 pages of apartment listings.
# You have 4590 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 4566 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 4542 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 4518 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 4494 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 4470 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 4445 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 4422 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 4398 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 4374 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 4349 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 4326 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 4302 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 4277 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 4253 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 4230 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 4205 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 4182 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 4158 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 4133 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 4110 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 4086 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 4062 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 4038 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 4014 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 3990 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 3966 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 3941 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 3918 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 3894 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 3870 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 3846 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 3822 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 3797 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 3773 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 3749 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 3726 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 3702 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 3678 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 3654 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 3629 listings left to go
